# %%
A1 = 0.0005654970871226156
B1 = -0.3324847832818661
C1 = 288.5335802138458
x = 800
Y1 = int( A1 * x ** 2 + B1 * x + C1)
print(Y1)
# Out:
# 332

# %%
A2 = 0.00043770234807127053
B2 = -0.023351473158883466
C2 = 67.40080052988358
x = 700
Y2 = int( A2 * x ** 2 + B2 * x + C2)
print(Y2)
# Out:
# 265

# %%
import matplotlib.pyplot as plt

ys = [304.05128205128204, 620.4727272727273, 922.1028037383178, 1219.6698113207547, 1498.2075471698113, 1162.6958762886597,
2434.3076923076924, 2721.766990291262, 2958.673076923077, 3467.5, 4475.658227848101, 4899.4078947368425, 5081.597402597403,
5612.8493150684935, 3664.1639344262294, 6808.691176470588, 7363.338461538461, 6994.338028169014, 6027.058139534884,
4299.543307086614, 3379.8255813953488, 3007.1153846153848, 3187.4761904761904, 2705.6059479553905, 2468.5882352941176,
2671.0548780487807, 2899.3993902439024, 2535.386473429952, 2718.2237762237764, 2786.0708154506437, 3079.804721030043,
2985.739776951673, 3317.5880149812733, 3861.121756487026]
xs = [x for x in range(len(ys))]
plt.plot(xs, ys)
plt.show
plt.close
# Out:
# <function matplotlib.pyplot.close>

# %% [markdown]
# # **Plot Bbox number welding video**

# %%
import matplotlib.pyplot as plt





ys = [39, 42, 44, 39, 40, 45, 45, 41, 40, 43, 42, 41, 37, 35, 34, 37, 43, 42, 44, 42, 40, 39, 40, 41, 39, 36, 40, 38, 38, 37, 39, 38, 37, 38, 41, 37, 39, 40, 40, 38, 40, 44, 43, 76, 79, 80, 78, 75, 77, 76, 75, 79, 75, 79, 76, 75, 72, 75, 73, 77, 72, 73, 74, 75, 74, 75, 77, 77, 76, 76, 77, 76, 80, 78, 55, 67, 53, 6, 81, 55, 50, 41, 41, 41, 41, 43, 45, 51, 53, 60, 68, 65, 66, 64, 67, 66, 64, 64, 64, 64, 65, 65, 65, 66, 67, 68, 68, 51, 45, 14, 0, 70, 66, 51, 45, 45, 45, 46, 32, 42, 38, 55, 35, 40, 36, 75, 32, 53, 27, 35, 91, 64, 60, 26, 16, 25, 50, 74, 61, 60, 61, 67, 28, 34, 43, 51, 49, 48, 57, 53, 38, 11, 5, 4, 7, 10, 13, 16, 28, 64, 95, 88, 74, 78, 77, 68, 48, 53, 58, 22, 67, 58, 52, 46, 50, 47, 46, 39, 48, 55, 49, 45, 51, 17, 0, 14, 50, 58, 45, 49, 50, 45, 44, 15, 19, 15, 14, 13, 21, 25, 18, 3, 6, 20, 20, 16, 13, 13, 11, 12, 11, 12, 13, 14, 19, 19, 23, 28, 18, 20, 24, 2, 5, 16, 18, 63, 34, 19, 18, 16, 20, 23, 13, 14, 28, 23, 28, 18, 19, 20, 19, 17, 7, 13, 19, 9, 36, 16, 16, 17, 15, 19, 15, 20, 18, 21, 20, 51, 58, 28, 0, 1, 0, 15, 20, 19, 44, 37, 33, 18, 12, 11, 33, 55, 27, 50, 63, 56, 35, 22, 7, 20, 24, 55, 61, 43, 18, 15, 62, 57, 43, 31, 37, 37, 36, 29, 32, 35, 33, 40, 39, 29, 30, 34, 29, 28, 26, 33, 36, 36, 37, 40, 41, 37, 39, 34, 35, 36, 36, 35, 32, 33, 33, 34, 35, 34, 34, 33, 33, 34, 30, 33, 37, 31, 30, 35, 34, 34, 32, 31, 32, 32, 31, 25, 22, 20, 20, 21, 21]




xs = [x for x in range(len(ys))]
plt.plot(xs, ys)
plt.show
plt.close
# Out:
# <function matplotlib.pyplot.close(fig=None)>
